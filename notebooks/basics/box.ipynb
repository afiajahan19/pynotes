# %%
import pandas as pd
import numpy as np

# %%
abc = np.array([
    [9, 13, 10],
    [7, 12, 9],
    [19, 11, 8]
])

# %%
abc
# Out:
# array([[ 9, 13, 10],
#        [ 7, 12,  9],
#        [19, 11,  8]])

# %%
df2 = pd.DataFrame(abc, columns=['breakfast', 'lunch', 'dinner'])

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.barh()
# Out:
# <Axes: >

# %%
df2.plot.barh(stacked=True)
# Out:
# <Axes: >
